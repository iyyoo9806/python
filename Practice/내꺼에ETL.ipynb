# %%
 # oracle 연결
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine,types

id = 'IYYOO98'
pw = 'kopo'
ip = '192.168.110.1'
port = '1521'
dbName = 'xe'


engine_oracle = create_engine('oracle+cx_oracle://{}:{}@{}:{}/{}'.format(id,pw,ip,port,dbName))

paramData = pd.read_csv("../dataset/근무지.csv",encoding="ms949")
# paramData = pd.read_csv("../dataset/부서.csv", encoding="ms949")
# paramData = pd.read_csv("../dataset/사원.csv", encoding="ms949")
# paramData = pd.read_csv("../dataset/직급.csv", encoding="ms949")

# %%
##가져온 데이터 오라클 DB에 테이블 이름 만들어서 전송
# tableName = destTable
# tableName = tableName.lower()
#### 문자컬럼에 대해서 varchar (100) 적용 _ 사용시 속도 SpeedUp 50배 
objectColumns = list(paramData.columns[paramData.dtypes == 'object'])
typeDict={}
maxLen = 100

for i in range(0, len(objectColumns)):
    # sawonData[i].str.len().max() 최대치 사용할 경우
    typeDict[ objectColumns[i] ] = types.VARCHAR(100)
#### 문자컬럼에 대해서 varchar (100) 적용 _ 사용시 속도 SpeedUp 50배 

paramData.to_sql(name="KNMUJI_TEST", if_exists="replace", con=engine_oracle,dtype=typeDict, index=False)
# paramData.to_sql(name="BUSEO_TEST", if_exists="replace", con=engine_oracle,dtype=typeDict, index=False)
# paramData.to_sql(name="SAWON_TEST", if_exists="replace", con=engine_oracle,dtype=typeDict, index=False)
# paramData.to_sql(name="JIKGB_TEST", if_exists="replace", con=engine_oracle,dtype=typeDict, index=False)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
# ...

# %%
data = pd.read_clipboard()

# %%
data
# Out:
#      SEG1   SEG2   SEG3  TARGETWEEK  YEAR  WEEK    QTY  FCST_W6  FCST_W5  \
# 0    PRDA  PRDA1  11311      202318  2023    18  21897  18033.0  18805.0
# 1    PRDA  PRDA1  11312      202318  2023    18  24771  24826.0  25753.0
# 2    PRDA  PRDA1  11313      202318  2023    18  31542  28685.0  31173.0
# 3    PRDA  PRDA1  11314      202318  2023    18   7044   7095.0   6928.0
# 4    PRDA  PRDA1  11315      202318  2023    18  12614  11913.0  12172.0
# ..    ...    ...    ...         ...   ...   ...    ...      ...      ...
# 192  PRDD  PRDD5  11252      202318  2023    18     44    216.0     34.0
# 193  PRDD  PRDD5  11253      202318  2023    18    917    812.0   1886.0
# 194  PRDD  PRDD5  11254      202318  2023    18   1032    648.0    524.0
# 195  PRDD  PRDD5  11255      202318  2023    18     81    256.0    175.0
# 196  PRDD  PRDD5  11256      202318  2023    18    515    498.0    583.0
#
#      FCST_W4  ...  ACC8W_W2  ACC8W_W1  ACC8W_QTY_W6  ACC8W_QTY_W5  \
# ...

# %%
objectColumns = list(data.columns[data.dtypes == 'object'])
typeDict={}
maxLen = 100

for i in range(0, len(objectColumns)):
    # sawonData[i].str.len().max() 최대치 사용할 경우
    typeDict[ objectColumns[i] ] = types.VARCHAR(100)
#### 문자컬럼에 대해서 varchar (100) 적용 _ 사용시 속도 SpeedUp 50배 

data.to_sql(name="정답2", if_exists="replace", con=engine_oracle,dtype=typeDict, index=False)
# Out:
# C:\Users\SMART01\anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name '정답2' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# 197
