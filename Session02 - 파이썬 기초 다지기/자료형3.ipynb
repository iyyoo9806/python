# %%
import pandas as pd

# %%
pd.read_csv("../dataset/kopo_customerdata.csv")
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# ...              ...       ...  ..     ...  ...      ...    ...       ...
# 299995        465757    State1   1    Male    0        1      0         0
# 299996       1890264    State1   1    Male    0        1      0         1
# 299997       1857537    State1   1  Female    0        2      0         0
# 299998       2209324    State1   1    Male    0        1      0         1
# 299999       1875146    State1   1    Male    0        1      0         1
#
#         TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# 0              30300          0      30300          0              0
# 1              46500          0      46500          0              0
# 2              22700          0          0      22700              0
# 3              31400          0      31400          0              0
# 4              44900          0          0      44900              0
# ...              ...        ...        ...        ...            ...
# 299995         40600          0      40600          0              0
# 299996         48000      48000          0          0              0
# 299997         32300          0          0      32300              0
# 299998         48500          0      48500          0              0
# 299999         16500          0          0      16500              0
#
#         IS_HIGHEND  CNT_VIST  GAP_VISIT
# 0                0         1          0
# 1                0         1          0
# 2                0         1          0
# 3                0         1          0
# 4                0         1          0
# ...            ...       ...        ...
# 299995           0         1          0
# 299996           0         1          0
# 299997           0         1          0
# 299998           0         1          0
# 299999           0         1          0
#
# [300000 rows x 16 columns]

# %%
stdCodeList = [111,222,333]
stdNameList = ["김효관", "홍길동", "타요"]
stdDf = pd.DataFrame( stdCodeList, columns =["학번"])
stdDf = pd.DataFrame( stdCodeList, columns =["학번"])
finalDf = pd.Dataframe( zip( stdCodeList,stdnameList),
             colums = ["학번","이름"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10628\1339615046.py in <module>
#       3 stdDf = pd.DataFrame( stdCodeList, columns =["학번"])
#       4 stdDf = pd.DataFrame( stdCodeList, columns =["학번"])
# ----> 5 finalDf = pd.Dataframe( zip( stdCodeList,stdnameList),
#       6              colums = ["학번","이름"])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
row1List = ["111","김"]
row2List = ["222","황"]
stdDF2 = pd.DataFrame([row1List,row2List],
            columns=["학번", "이름"])

# %%
stdDF2.to_csv("../dataset/stdDataout.csv")

# %%
## 한글 깨지면
stdDF2.to_csv("../dataset/stdDataout.csv",
    encoding ="ms949", index=False)
